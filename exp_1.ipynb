# %%
import pandas as pd
import tensorflow as tf
import numpy as np

# %%
def load_data(path):
    data = pd.read_csv(path, sep='\t', header=None)
    data = data.dropna()
    # Format: Devanagari, Latin, Frequency
    return list(zip(data[1], data[0]))  # Latin input, Devanagari target

train_pairs = load_data('hi.translit.sampled.train.tsv')
val_pairs = load_data('hi.translit.sampled.dev.tsv')

# Start/end tokens for target
input_texts = [inp for inp, _ in train_pairs]
target_texts = ['\t' + tgt + '\n' for _, tgt in train_pairs]

# Character sets
input_chars = sorted(set(''.join(input_texts)))
target_chars = sorted(set(''.join(target_texts)))

input_token_index = {char: i for i, char in enumerate(input_chars)}
target_token_index = {char: i for i, char in enumerate(target_chars)}

max_encoder_seq_length = max(len(txt) for txt in input_texts)
max_decoder_seq_length = max(len(txt) for txt in target_texts)

# %%
encoder_input_data = np.zeros((len(input_texts), max_encoder_seq_length, len(input_chars)))
decoder_input_data = np.zeros((len(target_texts), max_decoder_seq_length, len(target_chars)))
decoder_target_data = np.zeros((len(target_texts), max_decoder_seq_length, len(target_chars)))

for i, (input_text, target_text) in enumerate(zip(input_texts, target_texts)):
    for t, char in enumerate(input_text):
        encoder_input_data[i, t, input_token_index[char]] = 1.0
    for t, char in enumerate(target_text):
        decoder_input_data[i, t, target_token_index[char]] = 1.0
        if t > 0:
            decoder_target_data[i, t - 1, target_token_index[char]] = 1.0

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense

# Encoder
encoder_inputs = Input(shape=(None, len(input_chars)))
encoder_lstm = LSTM(256, return_state=True)
encoder_outputs, state_h, state_c = encoder_lstm(encoder_inputs)
encoder_states = [state_h, state_c]

# Decoder
decoder_inputs = Input(shape=(None, len(target_chars)))
decoder_lstm = LSTM(256, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs, initial_state=encoder_states)
decoder_dense = Dense(len(target_chars), activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_4       │ (None, None, 26)  │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_5       │ (None, None, 65)  │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_2 (LSTM)       │ [(None, 256),     │    289,792 │ input_layer_4[0]… │
# │                     │ (None, 256),      │            │                   │
# │                     │ (None, 256)]      │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_3 (LSTM)       │ [(None, None,     │    329,728 │ input_layer_5[0]… │
# │                     │ 256), (None,      │            │ lstm_2[0][1],     │
# │                     │ 256), (None,      │            │ lstm_2[0][2]      │
# │                     │ 256)]             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, None, 65)  │     16,705 │ lstm_3[0][0]      │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 636,225 (2.43 MB)
#  Trainable params: 636,225 (2.43 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(
    [encoder_input_data, decoder_input_data],
    decoder_target_data,
    batch_size=64,
    epochs=100,
    validation_split=0.2
)
# Out:
# Epoch 1/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.1853 - loss: 0.7319 - val_accuracy: 0.0871 - val_loss: 1.1615
# Epoch 2/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.1867 - loss: 0.7257 - val_accuracy: 0.0869 - val_loss: 1.1559
# Epoch 3/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.1880 - loss: 0.7212 - val_accuracy: 0.0868 - val_loss: 1.1571
# Epoch 4/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.1904 - loss: 0.7147 - val_accuracy: 0.0875 - val_loss: 1.1732
# Epoch 5/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.1908 - loss: 0.7094 - val_accuracy: 0.0853 - val_loss: 1.1537
# Epoch 6/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.1922 - loss: 0.7073 - val_accuracy: 0.0864 - val_loss: 1.1656
# Epoch 7/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.1925 - loss: 0.7043 - val_accuracy: 0.0868 - val_loss: 1.1670
# Epoch 8/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.1949 - loss: 0.7020 - val_accuracy: 0.0902 - val_loss: 1.1385
# Epoch 9/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.1954 - loss: 0.6977 - val_accuracy: 0.0881 - val_loss: 1.1472
# Epoch 10/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.1965 - loss: 0.6915 - val_accuracy: 0.0888 - val_loss: 1.1543
# Epoch 11/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.1975 - loss: 0.6895 - val_accuracy: 0.0890 - val_loss: 1.1693
# Epoch 12/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.1998 - loss: 0.6829 - val_accuracy: 0.0890 - val_loss: 1.1620
# Epoch 13/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.2005 - loss: 0.6794 - val_accuracy: 0.0956 - val_loss: 1.1216
# Epoch 14/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.2007 - loss: 0.6775 - val_accuracy: 0.0884 - val_loss: 1.1659
# Epoch 15/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.2021 - loss: 0.6755 - val_accuracy: 0.0925 - val_loss: 1.1428
# Epoch 16/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.2021 - loss: 0.6714 - val_accuracy: 0.0866 - val_loss: 1.1905
# Epoch 17/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.2040 - loss: 0.6675 - val_accuracy: 0.0880 - val_loss: 1.1647
# Epoch 18/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.2043 - loss: 0.6636 - val_accuracy: 0.0921 - val_loss: 1.1476
# Epoch 19/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.2049 - loss: 0.6606 - val_accuracy: 0.0896 - val_loss: 1.1774
# Epoch 20/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.2066 - loss: 0.6566 - val_accuracy: 0.0919 - val_loss: 1.1641
# Epoch 21/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.2071 - loss: 0.6555 - val_accuracy: 0.0944 - val_loss: 1.1649
# Epoch 22/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.2084 - loss: 0.6520 - val_accuracy: 0.0914 - val_loss: 1.1769
# Epoch 23/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.2090 - loss: 0.6502 - val_accuracy: 0.0941 - val_loss: 1.1556
# Epoch 24/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.2093 - loss: 0.6470 - val_accuracy: 0.0917 - val_loss: 1.1673
# Epoch 25/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.2102 - loss: 0.6464 - val_accuracy: 0.0924 - val_loss: 1.1697
# Epoch 26/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.2099 - loss: 0.6414 - val_accuracy: 0.0923 - val_loss: 1.1604
# Epoch 27/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.2117 - loss: 0.6410 - val_accuracy: 0.0939 - val_loss: 1.1670
# Epoch 28/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.2123 - loss: 0.6378 - val_accuracy: 0.0950 - val_loss: 1.1675
# Epoch 29/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.2128 - loss: 0.6332 - val_accuracy: 0.0927 - val_loss: 1.1700
# Epoch 30/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.2141 - loss: 0.6337 - val_accuracy: 0.0953 - val_loss: 1.1522
# Epoch 31/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.2142 - loss: 0.6331 - val_accuracy: 0.0935 - val_loss: 1.1749
# Epoch 32/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.2145 - loss: 0.6275 - val_accuracy: 0.0958 - val_loss: 1.1422
# Epoch 33/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.2161 - loss: 0.6293 - val_accuracy: 0.0928 - val_loss: 1.1713
# Epoch 34/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.2159 - loss: 0.6257 - val_accuracy: 0.0943 - val_loss: 1.1524
# Epoch 35/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.2175 - loss: 0.6226 - val_accuracy: 0.0945 - val_loss: 1.1591
# Epoch 36/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.2172 - loss: 0.6202 - val_accuracy: 0.0961 - val_loss: 1.1491
# Epoch 37/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.2170 - loss: 0.6197 - val_accuracy: 0.0919 - val_loss: 1.1591
# Epoch 38/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.2177 - loss: 0.6194 - val_accuracy: 0.0918 - val_loss: 1.1875
# Epoch 39/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.2191 - loss: 0.6149 - val_accuracy: 0.0959 - val_loss: 1.1480
# Epoch 40/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.2189 - loss: 0.6133 - val_accuracy: 0.0896 - val_loss: 1.1933
# Epoch 41/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.2192 - loss: 0.6132 - val_accuracy: 0.0910 - val_loss: 1.1857
# Epoch 42/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.2200 - loss: 0.6084 - val_accuracy: 0.0916 - val_loss: 1.1853
# Epoch 43/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.2206 - loss: 0.6088 - val_accuracy: 0.0908 - val_loss: 1.1917
# Epoch 44/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.2206 - loss: 0.6085 - val_accuracy: 0.0913 - val_loss: 1.1855
# Epoch 45/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.2219 - loss: 0.6058 - val_accuracy: 0.0940 - val_loss: 1.1598
# Epoch 46/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.2216 - loss: 0.6026 - val_accuracy: 0.0911 - val_loss: 1.2079
# Epoch 47/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.2217 - loss: 0.6022 - val_accuracy: 0.0905 - val_loss: 1.1981
# Epoch 48/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.2234 - loss: 0.6008 - val_accuracy: 0.0900 - val_loss: 1.1769
# Epoch 49/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.2253 - loss: 0.6013 - val_accuracy: 0.0923 - val_loss: 1.1889
# Epoch 50/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.2234 - loss: 0.5985 - val_accuracy: 0.0903 - val_loss: 1.1962
# Epoch 51/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.2239 - loss: 0.5969 - val_accuracy: 0.0927 - val_loss: 1.1796
# Epoch 52/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.2254 - loss: 0.5961 - val_accuracy: 0.0930 - val_loss: 1.1693
# Epoch 53/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.2262 - loss: 0.5932 - val_accuracy: 0.0948 - val_loss: 1.1661
# Epoch 54/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.2261 - loss: 0.5936 - val_accuracy: 0.0926 - val_loss: 1.1933
# Epoch 55/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.2266 - loss: 0.5922 - val_accuracy: 0.0929 - val_loss: 1.1728
# Epoch 56/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.2273 - loss: 0.5895 - val_accuracy: 0.0909 - val_loss: 1.1854
# Epoch 57/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.2290 - loss: 0.5888 - val_accuracy: 0.0944 - val_loss: 1.1877
# Epoch 58/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.2291 - loss: 0.5868 - val_accuracy: 0.0933 - val_loss: 1.1859
# Epoch 59/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.2284 - loss: 0.5860 - val_accuracy: 0.0926 - val_loss: 1.1818
# Epoch 60/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.2296 - loss: 0.5839 - val_accuracy: 0.0917 - val_loss: 1.1981
# Epoch 61/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.2291 - loss: 0.5844 - val_accuracy: 0.0904 - val_loss: 1.1910
# Epoch 62/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.2304 - loss: 0.5831 - val_accuracy: 0.0912 - val_loss: 1.1947
# Epoch 63/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.2303 - loss: 0.5818 - val_accuracy: 0.0915 - val_loss: 1.1939
# Epoch 64/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.2303 - loss: 0.5788 - val_accuracy: 0.0931 - val_loss: 1.1862
# Epoch 65/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.2311 - loss: 0.5781 - val_accuracy: 0.0920 - val_loss: 1.1916
# Epoch 66/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.2315 - loss: 0.5795 - val_accuracy: 0.0931 - val_loss: 1.1960
# Epoch 67/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.2313 - loss: 0.5767 - val_accuracy: 0.0894 - val_loss: 1.2074
# Epoch 68/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.2319 - loss: 0.5740 - val_accuracy: 0.0907 - val_loss: 1.2082
# Epoch 69/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.2331 - loss: 0.5751 - val_accuracy: 0.0902 - val_loss: 1.1995
# Epoch 70/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.2335 - loss: 0.5723 - val_accuracy: 0.0901 - val_loss: 1.2185
# Epoch 71/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.2343 - loss: 0.5728 - val_accuracy: 0.0905 - val_loss: 1.2159
# Epoch 72/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.2336 - loss: 0.5719 - val_accuracy: 0.0895 - val_loss: 1.2204
# Epoch 73/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.2337 - loss: 0.5700 - val_accuracy: 0.0901 - val_loss: 1.2013
# Epoch 74/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.2342 - loss: 0.5688 - val_accuracy: 0.0902 - val_loss: 1.2021
# Epoch 75/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.2353 - loss: 0.5669 - val_accuracy: 0.0899 - val_loss: 1.2057
# Epoch 76/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.2353 - loss: 0.5669 - val_accuracy: 0.0890 - val_loss: 1.2081
# Epoch 77/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.2357 - loss: 0.5642 - val_accuracy: 0.0908 - val_loss: 1.2113
# Epoch 78/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.2365 - loss: 0.5631 - val_accuracy: 0.0901 - val_loss: 1.2038
# Epoch 79/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.2359 - loss: 0.5642 - val_accuracy: 0.0849 - val_loss: 1.2138
# Epoch 80/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.2374 - loss: 0.5613 - val_accuracy: 0.0929 - val_loss: 1.1875
# Epoch 81/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.2368 - loss: 0.5605 - val_accuracy: 0.0890 - val_loss: 1.2039
# Epoch 82/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.2377 - loss: 0.5592 - val_accuracy: 0.0879 - val_loss: 1.2084
# Epoch 83/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.2379 - loss: 0.5601 - val_accuracy: 0.0894 - val_loss: 1.1911
# Epoch 84/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.2373 - loss: 0.5601 - val_accuracy: 0.0928 - val_loss: 1.1965
# Epoch 85/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.2382 - loss: 0.5573 - val_accuracy: 0.0891 - val_loss: 1.2078
# Epoch 86/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.2393 - loss: 0.5581 - val_accuracy: 0.0918 - val_loss: 1.1938
# Epoch 87/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.2382 - loss: 0.5576 - val_accuracy: 0.0900 - val_loss: 1.2021
# Epoch 88/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.2395 - loss: 0.5566 - val_accuracy: 0.0872 - val_loss: 1.2159
# Epoch 89/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.2403 - loss: 0.5537 - val_accuracy: 0.0852 - val_loss: 1.2359
# Epoch 90/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.2397 - loss: 0.5527 - val_accuracy: 0.0889 - val_loss: 1.1911
# Epoch 91/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.2406 - loss: 0.5529 - val_accuracy: 0.0889 - val_loss: 1.1925
# Epoch 92/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.2415 - loss: 0.5518 - val_accuracy: 0.0883 - val_loss: 1.2119
# Epoch 93/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.2399 - loss: 0.5501 - val_accuracy: 0.0895 - val_loss: 1.2027
# Epoch 94/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.2409 - loss: 0.5492 - val_accuracy: 0.0911 - val_loss: 1.1788
# Epoch 95/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.2415 - loss: 0.5472 - val_accuracy: 0.0890 - val_loss: 1.2006
# Epoch 96/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.2420 - loss: 0.5478 - val_accuracy: 0.0886 - val_loss: 1.2215
# Epoch 97/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.2421 - loss: 0.5467 - val_accuracy: 0.0869 - val_loss: 1.2129
# Epoch 98/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.2421 - loss: 0.5471 - val_accuracy: 0.0880 - val_loss: 1.2075
# Epoch 99/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.2415 - loss: 0.5463 - val_accuracy: 0.0852 - val_loss: 1.2251
# Epoch 100/100
# 553/553 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.2439 - loss: 0.5432 - val_accuracy: 0.0869 - val_loss: 1.2131

# %%
# Encoder model
encoder_model = Model(encoder_inputs, encoder_states)

# Decoder model
decoder_state_input_h = Input(shape=(256,))
decoder_state_input_c = Input(shape=(256,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]

decoder_outputs, state_h, state_c = decoder_lstm(
    decoder_inputs, initial_state=decoder_states_inputs
)
decoder_states = [state_h, state_c]
decoder_outputs = decoder_dense(decoder_outputs)

decoder_model = Model(
    [decoder_inputs] + decoder_states_inputs,
    [decoder_outputs] + decoder_states
)

# %%
reverse_input_char_index = {i: char for char, i in input_token_index.items()}
reverse_target_char_index = {i: char for char, i in target_token_index.items()}

def decode_sequence(input_seq):
    # Encode input
    states_value = encoder_model.predict(input_seq)

    # Generate empty target sequence with start character
    target_seq = np.zeros((1, 1, len(target_chars)))
    target_seq[0, 0, target_token_index['\t']] = 1.0

    decoded_sentence = ''
    for _ in range(max_decoder_seq_length):
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value)

        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_target_char_index[sampled_token_index]
        decoded_sentence += sampled_char

        if sampled_char == '\n':
            break

        # Update target sequence
        target_seq = np.zeros((1, 1, len(target_chars)))
        target_seq[0, 0, sampled_token_index] = 1.0

        states_value = [h, c]

    return decoded_sentence.strip()

# %%
for seq_index in range(10):
    input_seq = encoder_input_data[seq_index:seq_index+1]
    decoded = decode_sequence(input_seq)
    print(f"Input: {input_texts[seq_index]} → Prediction: {decoded} | Target: {target_texts[seq_index]}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Input: an → Prediction: अ | Target: 	अं
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Input: ankganit → Prediction: अंकगना | Target: 	अंकगणित
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Input: uncle → Prediction: अंना | Target: 	अंकल
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Input: ankur → Prediction: अंका | Target: 	अंकुर
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Input: ankuran → Prediction: अंकुरा | Target: 	अंकुरण
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Input: ankurit → Prediction: अंकुरर | Target: 	अंकुरित
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Input: aankush → Prediction: अंकका | Target: 	अंकुश
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Input: ankush → Prediction: अंकका | Target: 	अंकुश
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Input: ang → Prediction: अ | Target: 	अंग
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Input: anga → Prediction: अंा | Target: 	अंग

# %%
def encode_input_text(input_text):
    encoder_input = np.zeros((1, max_encoder_seq_length, len(input_chars)))
    for t, char in enumerate(input_text):
        if char in input_token_index:
            encoder_input[0, t, input_token_index[char]] = 1.0
    return encoder_input

while True:
    user_input = input("Enter a Latin word (or type 'exit' to quit): ").strip().lower()
    if user_input == 'exit':
        break

    encoded_input = encode_input_text(user_input)
    prediction = decode_sequence(encoded_input)
    print(f"Predicted Devanagari: {prediction}")
# Out:
# Enter a Latin word (or type 'exit' to quit): me
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Predicted Devanagari: म
# Enter a Latin word (or type 'exit' to quit): aam
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Predicted Devanagari: आ
# Enter a Latin word (or type 'exit' to quit): aama
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Predicted Devanagari: आा
# Enter a Latin word (or type 'exit' to quit): andhar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Predicted Devanagari: अंाा
# Enter a Latin word (or type 'exit' to quit): amber
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Predicted Devanagari: अमबरा
# Enter a Latin word (or type 'exit' to quit): aakash
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Predicted Devanagari: आकक
# Enter a Latin word (or type 'exit' to quit): akila
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Predicted Devanagari: अकिा
# Enter a Latin word (or type 'exit' to quit): ankush
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Predicted Devanagari: अंकाा
# Enter a Latin word (or type 'exit' to quit): uppal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Predicted Devanagari: उपा
# Enter a Latin word (or type 'exit' to quit): udbar
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Predicted Devanagari: उद्रा
# Enter a Latin word (or type 'exit' to quit): upved
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Predicted Devanagari: उपवा
# Enter a Latin word (or type 'exit' to quit): eli
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Predicted Devanagari: एा
# Enter a Latin word (or type 'exit' to quit): oakland
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Predicted Devanagari: ओलका
# Enter a Latin word (or type 'exit' to quit): audio
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Predicted Devanagari: औडा
# Enter a Latin word (or type 'exit' to quit): auto
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Predicted Devanagari: आ
# Enter a Latin word (or type 'exit' to quit): ono
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Predicted Devanagari: आ
# Enter a Latin word (or type 'exit' to quit): aur
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Predicted Devanagari: आ
# Enter a Latin word (or type 'exit' to quit): ohio
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Predicted Devanagari: आ
# Enter a Latin word (or type 'exit' to quit): uppal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Predicted Devanagari: उपा
# Enter a Latin word (or type 'exit' to quit): katlaa
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Predicted Devanagari: कटाा
# Enter a Latin word (or type 'exit' to quit): kpol
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Predicted Devanagari: बोल
# Enter a Latin word (or type 'exit' to quit): exit

# %%
def encode_input_text(input_text):
    encoder_input = np.zeros((1, max_encoder_seq_length, len(input_chars)))
    for t, char in enumerate(input_text):
        if char in input_token_index:
            encoder_input[0, t, input_token_index[char]] = 1.0
    return encoder_input

while True:
    user_input = input("Enter a Latin word (or type 'exit' to quit): ").strip().lower()
    if user_input == 'exit':
        break

    encoded_input = encode_input_text(user_input)
    prediction = decode_sequence(encoded_input)
    print(f"Predicted Devanagari: {prediction}")
# Out:
# Enter a Latin word (or type 'exit' to quit): aakash
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Predicted Devanagari: आक्ा
# Enter a Latin word (or type 'exit' to quit): uppal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Predicted Devanagari: अप्
# Enter a Latin word (or type 'exit' to quit): hyd
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Predicted Devanagari: एया
# Enter a Latin word (or type 'exit' to quit): ela
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Predicted Devanagari: एल
# Enter a Latin word (or type 'exit' to quit): amber
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Predicted Devanagari: अमरा
# Enter a Latin word (or type 'exit' to quit): exit
